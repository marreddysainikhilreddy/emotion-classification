# %%
# %pip install comet-ml torch numpy scikit-learn transformers nltk datasets huggingface_hub accelerate -U ipywidgets
# transformers[torch]
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: comet-ml in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (3.35.3)
# Requirement already satisfied: torch in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: numpy in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (1.26.2)
# Requirement already satisfied: scikit-learn in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (1.3.2)
# Requirement already satisfied: transformers in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (4.35.2)
# Requirement already satisfied: nltk in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: datasets in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (2.15.0)
# Requirement already satisfied: huggingface_hub in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (0.19.4)
# Requirement already satisfied: accelerate in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (0.25.0)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (4.20.0)
# Requirement already satisfied: psutil>=5.6.3 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (5.9.6)
# Requirement already satisfied: python-box<7.0.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (6.1.0)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (2.31.0)
# Requirement already satisfied: semantic-version>=2.8.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (2.10.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (1.37.1)
# Requirement already satisfied: simplejson in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (3.19.2)
# Requirement already satisfied: six in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (1.16.0)
# Requirement already satisfied: urllib3>=1.21.1 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (2.1.0)
# Requirement already satisfied: websocket-client<1.4.0,>=0.55.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (1.3.3)
# Requirement already satisfied: wrapt>=1.11.2 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (1.16.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (3.0.3)
# Requirement already satisfied: everett[ini]<3.2.0,>=1.0.1 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (3.1.0)
# Requirement already satisfied: dulwich!=0.20.33,>=0.20.6 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (0.21.6)
# Requirement already satisfied: rich>=13.3.2 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from comet-ml) (13.7.0)
# Requirement already satisfied: filelock in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from torch) (4.8.0)
# Requirement already satisfied: sympy in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: scipy>=1.5.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: click in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from datasets) (14.0.1)
# Requirement already satisfied: pyarrow-hotfix in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from datasets) (2.1.3)
# Requirement already satisfied: xxhash in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: aiohttp in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from datasets) (3.9.1)
# Requirement already satisfied: comm>=0.1.3 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from ipywidgets) (8.18.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from ipywidgets) (5.13.0)
# Collecting widgetsnbextension~=4.0.9
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 27.2 MB/s eta 0:00:0031m30.2 MB/s eta 0:00:01
# Collecting jupyterlab-widgets~=3.0.9
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.9/214.9 kB 22.0 MB/s eta 0:00:00
# Requirement already satisfied: configobj in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from everett[ini]<3.2.0,>=1.0.1->comet-ml) (5.0.8)
# Requirement already satisfied: attrs>=17.3.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: decorator in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from requests>=2.18.4->comet-ml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from requests>=2.18.4->comet-ml) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from requests>=2.18.4->comet-ml) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from rich>=13.3.2->comet-ml) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet-ml) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/linkaiyuan/文件/github/transformer-exploration/venv/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.1 jupyterlab-widgets-3.0.9 widgetsnbextension-4.0.9
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import comet_ml
import os
from transformers.integrations import CometCallback
# from google.colab import userdata <- only needed if running on colab

# retrieve comet api key for logging data
#comet_api_key = userdata.get('comet_api_key')
comet_api_key = 'l67W8m5hgKQu6YzOOuGdGEpBt' # hard-coded, if running on colab, put api key into 'secrets' tab
if not comet_api_key:
  raise ValueError("Comet API key not found.")
else:
  print("Comet API key retrieved successfully.")
# Set the COMET_API_KEY environment variable
os.environ['COMET_API_KEY'] = comet_api_key
# set callback variable for logging to comet
comet_callback = CometCallback()
print(1)


from huggingface_hub import notebook_login

notebook_login()

import os
os.environ['HUGGINGFACE_HUB_TOKEN'] = 'l67W8m5hgKQu6YzOOuGdGEpBt'
# Out:
# Comet API key retrieved successfully.
# 1
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
def multi_label_metrics(predictions, labels, threshold=0.5, experiment=None):
    sigmoid = torch.nn.Sigmoid()
    probs = sigmoid(torch.Tensor(predictions))
    y_pred = np.zeros(probs.shape)
    y_pred[np.where(probs >= threshold)] = 1
    y_true = labels

    f1_micro_average = f1_score(y_true=y_true, y_pred=y_pred, average='micro')
    roc_auc = roc_auc_score(y_true, y_pred, average='micro')
    accuracy = accuracy_score(y_true, y_pred)

    metrics = {'f1': f1_micro_average, 'roc_auc': roc_auc, 'accuracy': accuracy}

    # Log metrics to Comet.ml
    if experiment is not None:
        experiment.log_metrics(metrics)

    return metrics

# %%
from huggingface_hub import login
login(token = "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")

import pandas as pd
from datasets import Dataset, DatasetDict

file_paths = [f'../self_report_data/Se-Re_Emotion_dataset_{i}.csv' for i in range(11)]

dfs = []
for file in file_paths:
    df = pd.read_csv(file, encoding='utf-16', delimiter='\t')  # Specify UTF-16 encoding here
    dfs.append(df)

# Concatenate all dataframes
df = pd.concat(dfs, ignore_index=True)

# Verify the DataFrame's columns
print(df.columns)  # Ensure that columns are read correctly
# Out:
# Index(['id', 'text', 'Emotion', 'Hashtag'], dtype='object')

# %%
# Select only the relevant columns
df = df[['text', 'Emotion']]

# Create a Hugging Face Dataset from the DataFrame
dataset = Dataset.from_pandas(df)


from transformers import AutoModelForSequenceClassification, AutoTokenizer

# Specify the path to your checkpoint directory
checkpoint_path = "./model_output/checkpoint-22000"

# Load the tokenizer and the model using the checkpoint
tokenizer = AutoTokenizer.from_pretrained(checkpoint_path)
model = AutoModelForSequenceClassification.from_pretrained(checkpoint_path)
emotions = [
    'amusement',
    'anger',
    'annoyance',
    'curiosity',
    'disgust',
    'embarrassment',
    'fear',
    'gratitude',
    'grief',
    'joy',
    'love',
    'optimism',
    'sadness',
    'neutral'
]



id2label = {idx:label for idx, label in enumerate(emotions)}
label2id = {label:idx for idx, label in enumerate(emotions)}


def tokenize_and_encode(examples):
    tokenized_inputs = tokenizer(
        examples['text'], 
        padding='max_length', 
        truncation=True, 
        max_length=128
    )
    return tokenized_inputs


tokenized_dataset = dataset.map(tokenize_and_encode, batched=True)


def one_hot_encode_labels(example):
    labels = np.zeros(len(emotions), dtype=np.float32)  # Change dtype to float32
    labels[label2id[example['Emotion']]] = 1
    example['labels'] = labels.tolist()
    return example


tokenized_dataset = tokenized_dataset.map(one_hot_encode_labels)



# Split the dataset into training, validation, and test sets
train_test_split = tokenized_dataset.train_test_split(test_size=0.1)
train_validation_split = train_test_split['train'].train_test_split(test_size=0.1)

dataset = DatasetDict({
    'train': train_validation_split['train'],
    'validation': train_validation_split['test'],
    'test': train_test_split['test']
})
# Out:
# Map: 100%|███████████████████████████████████████████████████████████████████████████████| 2750011/2750011 [02:23<00:00, 19187.07 examples/s]
# Map: 100%|███████████████████████████████████████████████████████████████████████████████| 2750011/2750011 [02:53<00:00, 15877.96 examples/s]

# %%
from transformers import Trainer, TrainingArguments

# Define your compute_metrics function (this is just a placeholder)
def multi_label_metrics(predictions, labels, threshold=0.5, experiment=None):
    sigmoid = torch.nn.Sigmoid()
    probs = sigmoid(torch.Tensor(predictions))
    y_pred = np.zeros(probs.shape)
    y_pred[np.where(probs >= threshold)] = 1
    y_true = labels

    f1_micro_average = f1_score(y_true=y_true, y_pred=y_pred, average='micro')
    roc_auc = roc_auc_score(y_true, y_pred, average='micro')
    accuracy = accuracy_score(y_true, y_pred)

    metrics = {'f1': f1_micro_average, 'roc_auc': roc_auc, 'accuracy': accuracy}

    # Log metrics to Comet.ml
    if experiment is not None:
        experiment.log_metrics(metrics)

    return metrics
    
training_args = TrainingArguments(
    output_dir='./model_output',
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
    # Other arguments as needed
)

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset['train'],
    eval_dataset=dataset['validation'],
    tokenizer=tokenizer,
    # If you have a compute_metrics function, include it here
    compute_metrics=multi_label_metrics
)

# Train the model
trainer.train()

# Evaluate the model
trainer.evaluate(dataset['test'])

# Save the fine-tuned model
model.save_pretrained('./fine_tuned')
# Out:
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/aaaaaiden/huggingface/3246e3c658124bebae7823fa7a0e7703
# COMET INFO:   Parameters:
# COMET INFO:     args/_n_gpu                             : 1
# COMET INFO:     args/_no_sync_in_gradient_accumulation  : True
# COMET INFO:     args/_setup_devices                     : mps
# COMET INFO:     args/adafactor                          : False
# COMET INFO:     args/adam_beta1                         : 0.9
# COMET INFO:     args/adam_beta2                         : 0.999
# COMET INFO:     args/adam_epsilon                       : 1e-08
# COMET INFO:     args/auto_find_batch_size               : False
# COMET INFO:     args/bf16                               : False
# COMET INFO:     args/bf16_full_eval                     : False
# COMET INFO:     args/data_seed                          : None
# COMET INFO:     args/dataloader_drop_last               : False
# COMET INFO:     args/dataloader_num_workers             : 0
# COMET INFO:     args/dataloader_pin_memory              : True
# COMET INFO:     args/ddp_backend                        : None
# COMET INFO:     args/ddp_broadcast_buffers              : None
# COMET INFO:     args/ddp_bucket_cap_mb                  : None
# COMET INFO:     args/ddp_find_unused_parameters         : None
# COMET INFO:     args/ddp_timeout                        : 1800
# COMET INFO:     args/ddp_timeout_delta                  : 0:30:00
# COMET INFO:     args/debug                              : []
# COMET INFO:     args/deepspeed                          : None
# COMET INFO:     args/deepspeed_plugin                   : None
# COMET INFO:     args/default_optim                      : adamw_torch
# COMET INFO:     args/device                             : mps
# COMET INFO:     args/disable_tqdm                       : False
# COMET INFO:     args/dispatch_batches                   : None
# COMET INFO:     args/distributed_state                  : Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: mps
#
# COMET INFO:     args/do_eval                            : True
# COMET INFO:     args/do_predict                         : False
# COMET INFO:     args/do_train                           : False
# COMET INFO:     args/eval_accumulation_steps            : None
# COMET INFO:     args/eval_batch_size                    : 16
# COMET INFO:     args/eval_delay                         : 0
# COMET INFO:     args/eval_steps                         : None
# COMET INFO:     args/evaluation_strategy                : IntervalStrategy.EPOCH
# COMET INFO:     args/fp16                               : False
# COMET INFO:     args/fp16_backend                       : auto
# COMET INFO:     args/fp16_full_eval                     : False
# COMET INFO:     args/fp16_opt_level                     : O1
# COMET INFO:     args/framework                          : pt
# COMET INFO:     args/fsdp                               : []
# COMET INFO:     args/fsdp_config                        : {'min_num_params': 0, 'xla': False, 'xla_fsdp_grad_ckpt': False}
# COMET INFO:     args/fsdp_min_num_params                : 0
# COMET INFO:     args/fsdp_transformer_layer_cls_to_wrap : None
# COMET INFO:     args/full_determinism                   : False
# COMET INFO:     args/gradient_accumulation_steps        : 1
# COMET INFO:     args/gradient_checkpointing             : False
# COMET INFO:     args/gradient_checkpointing_kwargs      : None
# COMET INFO:     args/greater_is_better                  : None
# COMET INFO:     args/group_by_length                    : False
# COMET INFO:     args/half_precision_backend             : auto
# COMET INFO:     args/hub_always_push                    : False
# COMET INFO:     args/hub_model_id                       : None
# COMET INFO:     args/hub_private_repo                   : False
# COMET INFO:     args/hub_strategy                       : HubStrategy.EVERY_SAVE
# COMET INFO:     args/hub_token                          : None
# COMET INFO:     args/ignore_data_skip                   : False
# COMET INFO:     args/include_inputs_for_metrics         : False
# COMET INFO:     args/include_tokens_per_second          : False
# COMET INFO:     args/jit_mode_eval                      : False
# COMET INFO:     args/label_names                        : None
# COMET INFO:     args/label_smoothing_factor             : 0.0
# COMET INFO:     args/learning_rate                      : 2e-05
# COMET INFO:     args/length_column_name                 : length
# COMET INFO:     args/load_best_model_at_end             : False
# COMET INFO:     args/local_process_index                : 0
# COMET INFO:     args/local_rank                         : 0
# COMET INFO:     args/log_level                          : passive
# COMET INFO:     args/log_level_replica                  : warning
# COMET INFO:     args/log_on_each_node                   : True
# COMET INFO:     args/logging_dir                        : ./model_output/runs/Dec08_22-31-47_linkaiyuandeMacBook-Pro.local
# COMET INFO:     args/logging_first_step                 : False
# COMET INFO:     args/logging_nan_inf_filter             : True
# COMET INFO:     args/logging_steps                      : 500
# COMET INFO:     args/logging_strategy                   : IntervalStrategy.STEPS
# COMET INFO:     args/lr_scheduler_type                  : SchedulerType.LINEAR
# COMET INFO:     args/max_grad_norm                      : 1.0
# COMET INFO:     args/max_steps                          : -1
# COMET INFO:     args/metric_for_best_model              : None
# COMET INFO:     args/mp_parameters                      :
# COMET INFO:     args/n_gpu                              : 1
# COMET INFO:     args/neftune_noise_alpha                : None
# COMET INFO:     args/no_cuda                            : False
# COMET INFO:     args/num_train_epochs                   : 3
# COMET INFO:     args/optim                              : OptimizerNames.ADAMW_TORCH
# COMET INFO:     args/optim_args                         : None
# COMET INFO:     args/output_dir                         : ./model_output
# COMET INFO:     args/overwrite_output_dir               : False
# COMET INFO:     args/parallel_mode                      : ParallelMode.NOT_PARALLEL
# COMET INFO:     args/past_index                         : -1
# COMET INFO:     args/per_device_eval_batch_size         : 16
# COMET INFO:     args/per_device_train_batch_size        : 16
# COMET INFO:     args/per_gpu_eval_batch_size            : None
# COMET INFO:     args/per_gpu_train_batch_size           : None
# COMET INFO:     args/place_model_on_device              : True
# COMET INFO:     args/prediction_loss_only               : False
# COMET INFO:     args/process_index                      : 0
# COMET INFO:     args/push_to_hub                        : False
# COMET INFO:     args/push_to_hub_model_id               : None
# COMET INFO:     args/push_to_hub_organization           : None
# COMET INFO:     args/push_to_hub_token                  : None
# COMET INFO:     args/ray_scope                          : last
# COMET INFO:     args/remove_unused_columns              : True
# COMET INFO:     args/report_to                          : ['comet_ml']
# COMET INFO:     args/resume_from_checkpoint             : None
# COMET INFO:     args/run_name                           : ./model_output
# COMET INFO:     args/save_on_each_node                  : False
# COMET INFO:     args/save_safetensors                   : True
# COMET INFO:     args/save_steps                         : 500
# COMET INFO:     args/save_strategy                      : IntervalStrategy.STEPS
# COMET INFO:     args/save_total_limit                   : None
# COMET INFO:     args/seed                               : 42
# COMET INFO:     args/should_log                         : True
# COMET INFO:     args/should_save                        : True
# COMET INFO:     args/skip_memory_metrics                : True
# COMET INFO:     args/split_batches                      : False
# COMET INFO:     args/tf32                               : None
# COMET INFO:     args/torch_compile                      : False
# COMET INFO:     args/torch_compile_backend              : None
# COMET INFO:     args/torch_compile_mode                 : None
# COMET INFO:     args/torchdynamo                        : None
# COMET INFO:     args/tpu_metrics_debug                  : False
# COMET INFO:     args/tpu_num_cores                      : None
# COMET INFO:     args/train_batch_size                   : 16
# COMET INFO:     args/use_cpu                            : False
# COMET INFO:     args/use_ipex                           : False
# COMET INFO:     args/use_legacy_prediction_loop         : False
# COMET INFO:     args/use_mps_device                     : False
# COMET INFO:     args/warmup_ratio                       : 0.0
# COMET INFO:     args/warmup_steps                       : 0
# COMET INFO:     args/weight_decay                       : 0.01
# COMET INFO:     args/world_size                         : 1
# COMET INFO:     config/_auto_class                      : None
# COMET INFO:     config/_commit_hash                     : None
# COMET INFO:     config/_name_or_path                    : ./model_output/checkpoint-22000
# COMET INFO:     config/add_cross_attention              : False
# COMET INFO:     config/architectures                    : ['BertForSequenceClassification']
# COMET INFO:     config/attention_probs_dropout_prob     : 0.1
# COMET INFO:     config/attribute_map                    : {}
# COMET INFO:     config/bad_words_ids                    : None
# COMET INFO:     config/begin_suppress_tokens            : None
# COMET INFO:     config/bos_token_id                     : None
# COMET INFO:     config/chunk_size_feed_forward          : 0
# COMET INFO:     config/classifier_dropout               : None
# COMET INFO:     config/cross_attention_hidden_size      : None
# COMET INFO:     config/decoder_start_token_id           : None
# COMET INFO:     config/diversity_penalty                : 0.0
# COMET INFO:     config/do_sample                        : False
# COMET INFO:     config/early_stopping                   : False
# COMET INFO:     config/encoder_no_repeat_ngram_size     : 0
# COMET INFO:     config/eos_token_id                     : None
# COMET INFO:     config/exponential_decay_length_penalty : None
# COMET INFO:     config/finetuning_task                  : None
# COMET INFO:     config/forced_bos_token_id              : None
# COMET INFO:     config/forced_eos_token_id              : None
# COMET INFO:     config/gradient_checkpointing           : False
# COMET INFO:     config/hidden_act                       : gelu
# COMET INFO:     config/hidden_dropout_prob              : 0.1
# COMET INFO:     config/hidden_size                      : 1024
# COMET INFO:     config/id2label                         : {0: 'amusement', 1: 'anger', 2: 'annoyance', 3: 'curiosity', 4: 'disgust', 5: 'embarrassment', 6: 'fear', 7: 'gratitude', 8: 'grief', 9: 'joy', 10: 'love', 11: 'optimism', 12: 'sadness', 13: 'neutral'}
# COMET INFO:     config/initializer_range                : 0.02
# COMET INFO:     config/intermediate_size                : 4096
# COMET INFO:     config/is_composition                   : False
# COMET INFO:     config/is_decoder                       : False
# COMET INFO:     config/is_encoder_decoder               : False
# COMET INFO:     config/label2id                         : {'amusement': 0, 'anger': 1, 'annoyance': 2, 'curiosity': 3, 'disgust': 4, 'embarrassment': 5, 'fear': 6, 'gratitude': 7, 'grief': 8, 'joy': 9, 'love': 10, 'neutral': 13, 'optimism': 11, 'sadness': 12}
# COMET INFO:     config/layer_norm_eps                   : 1e-12
# COMET INFO:     config/length_penalty                   : 1.0
# COMET INFO:     config/max_length                       : 20
# COMET INFO:     config/max_position_embeddings          : 512
# COMET INFO:     config/min_length                       : 0
# COMET INFO:     config/model_type                       : bert
# COMET INFO:     config/name_or_path                     : ./model_output/checkpoint-22000
# COMET INFO:     config/no_repeat_ngram_size             : 0
# COMET INFO:     config/num_attention_heads              : 16
# COMET INFO:     config/num_beam_groups                  : 1
# COMET INFO:     config/num_beams                        : 1
# COMET INFO:     config/num_hidden_layers                : 24
# COMET INFO:     config/num_labels                       : 14
# COMET INFO:     config/num_return_sequences             : 1
# COMET INFO:     config/output_attentions                : False
# COMET INFO:     config/output_hidden_states             : False
# COMET INFO:     config/output_scores                    : False
# COMET INFO:     config/pad_token_id                     : 0
# COMET INFO:     config/position_embedding_type          : absolute
# COMET INFO:     config/prefix                           : None
# COMET INFO:     config/problem_type                     : multi_label_classification
# COMET INFO:     config/pruned_heads                     : {}
# COMET INFO:     config/remove_invalid_values            : False
# COMET INFO:     config/repetition_penalty               : 1.0
# COMET INFO:     config/return_dict                      : True
# COMET INFO:     config/return_dict_in_generate          : False
# COMET INFO:     config/sep_token_id                     : None
# COMET INFO:     config/suppress_tokens                  : None
# COMET INFO:     config/task_specific_params             : None
# COMET INFO:     config/temperature                      : 1.0
# COMET INFO:     config/tf_legacy_loss                   : False
# COMET INFO:     config/tie_encoder_decoder              : False
# COMET INFO:     config/tie_word_embeddings              : True
# COMET INFO:     config/tokenizer_class                  : None
# COMET INFO:     config/top_k                            : 50
# COMET INFO:     config/top_p                            : 1.0
# COMET INFO:     config/torch_dtype                      : torch.float32
# COMET INFO:     config/torchscript                      : False
# COMET INFO:     config/transformers_version             : 4.35.2
# COMET INFO:     config/type_vocab_size                  : 2
# COMET INFO:     config/typical_p                        : 1.0
# COMET INFO:     config/use_bfloat16                     : False
# COMET INFO:     config/use_cache                        : True
# COMET INFO:     config/use_return_dict                  : True
# COMET INFO:     config/vocab_size                       : 30522
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (705.26 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/aaaaaiden/huggingface/14d700e499884048baa3c33c15ae18a3
#
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='10' max='417660' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [    10/417660 00:13 < 199:26:59, 0.58 it/s, Epoch 0.00/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 32
#      21 trainer = Trainer(
#      22     model=model,
#      23     args=training_args,
#    (...)
#      28     # compute_metrics=compute_metrics
#      29 )
#      31 # Train the model
# ---> 32 trainer.train()
#      34 # Evaluate the model
#      35 trainer.evaluate(dataset['test'])
#
# File ~/文件/github/transformer-exploration/venv/lib/python3.11/site-packages/transformers/trainer.py:1555, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1553         hf_hub_utils.enable_progress_bars()
#    1554 else:
# -> 1555     return inner_training_loop(
#    1556         args=args,
#    1557         resume_from_checkpoint=resume_from_checkpoint,
#    1558         trial=trial,
#    1559         ignore_keys_for_eval=ignore_keys_for_eval,
#    1560     )
#
# File ~/文件/github/transformer-exploration/venv/lib/python3.11/site-packages/transformers/trainer.py:1910, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1904         self.accelerator.clip_grad_norm_(
#    1905             model.parameters(),
#    1906             args.max_grad_norm,
#    1907         )
#    1909 # Optimizer step
# -> 1910 self.optimizer.step()
#    1911 optimizer_was_run = not self.accelerator.optimizer_step_was_skipped
#    1912 if optimizer_was_run:
#    1913     # Delay optimizer scheduling until metrics are generated
#
# File ~/文件/github/transformer-exploration/venv/lib/python3.11/site-packages/accelerate/optimizer.py:145, in AcceleratedOptimizer.step(self, closure)
#     143     self._accelerate_step_called = False
#     144 else:
# --> 145     self.optimizer.step(closure)
#
# File ~/文件/github/transformer-exploration/venv/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:68, in LRScheduler.__init__.<locals>.with_counter.<locals>.wrapper(*args, **kwargs)
#      66 instance._step_count += 1
#      67 wrapped = func.__get__(instance, cls)
# ---> 68 return wrapped(*args, **kwargs)
#
# File ~/文件/github/transformer-exploration/venv/lib/python3.11/site-packages/torch/optim/optimizer.py:373, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     368         else:
#     369             raise RuntimeError(
#     370                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     371             )
# --> 373 out = func(*args, **kwargs)
#     374 self._optimizer_step_code()
#     376 # call optimizer step post hooks
#
# File ~/文件/github/transformer-exploration/venv/lib/python3.11/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~/文件/github/transformer-exploration/venv/lib/python3.11/site-packages/torch/optim/adamw.py:184, in AdamW.step(self, closure)
#     171     beta1, beta2 = group["betas"]
#     173     self._init_group(
#     174         group,
#     175         params_with_grad,
#    (...)
#     181         state_steps,
#     182     )
# --> 184     adamw(
#     185         params_with_grad,
#     186         grads,
#     187         exp_avgs,
#     188         exp_avg_sqs,
#     189         max_exp_avg_sqs,
#     190         state_steps,
#     191         amsgrad=amsgrad,
#     192         beta1=beta1,
#     193         beta2=beta2,
#     194         lr=group["lr"],
#     195         weight_decay=group["weight_decay"],
#     196         eps=group["eps"],
#     197         maximize=group["maximize"],
#     198         foreach=group["foreach"],
#     199         capturable=group["capturable"],
#     200         differentiable=group["differentiable"],
#     201         fused=group["fused"],
#     202         grad_scale=getattr(self, "grad_scale", None),
#     203         found_inf=getattr(self, "found_inf", None),
#     204     )
#     206 return loss
#
# File ~/文件/github/transformer-exploration/venv/lib/python3.11/site-packages/torch/optim/adamw.py:335, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     332 else:
#     333     func = _single_tensor_adamw
# --> 335 func(
#     336     params,
#     337     grads,
#     338     exp_avgs,
#     339     exp_avg_sqs,
#     340     max_exp_avg_sqs,
#     341     state_steps,
#     342     amsgrad=amsgrad,
#     343     beta1=beta1,
#     344     beta2=beta2,
#     345     lr=lr,
#     346     weight_decay=weight_decay,
#     347     eps=eps,
#     348     maximize=maximize,
#     349     capturable=capturable,
#     350     differentiable=differentiable,
#     351     grad_scale=grad_scale,
#     352     found_inf=found_inf,
#     353 )
#
# File ~/文件/github/transformer-exploration/venv/lib/python3.11/site-packages/torch/optim/adamw.py:464, in _single_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     462         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     463     else:
# --> 464         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     466     param.addcdiv_(exp_avg, denom, value=-step_size)
#     468 # Lastly, switch back to complex view
#
# KeyboardInterrupt:
